# 0    NaN NaN
# 1    NaN NaN
# 2    NaN NaN
# 3    NaN NaN
# 4    NaN NaN
# 5    NaN NaN
# 6    NaN NaN
# 7    NaN NaN
# 8    NaN NaN
# 9    NaN NaN
# 10   NaN NaN
# 11   NaN NaN
# 12   NaN NaN
# 13   NaN NaN
# 14   NaN NaN
# 15   NaN NaN
# 16   NaN NaN
# 17   NaN NaN
# 18   NaN NaN
# 19   NaN NaN

# %%
import pandas as pd
name = ['Bob', 'Tom', 'Jason', 'Marry', 'Julia', 'John', 'Cathy', 'Andy']
subject = ['Chinese', 'Math', 'Science', 'Music', 'PE', 'History']
scores = [[ 52,85,96,100,75,54],[40,98,93,54,33,20],[100,97,54,55,100,88],
 [72,67,64,53,87,83],[45,90,100,55,34,96], [99,47,85,56,60,100],
 [100,36,89,64,85,50],[85,36,45,79,84,39]]
df = pd.DataFrame(scores, index = name, columns = subject)
df
# Out:
#        Chinese  Math  Science  Music   PE  History
# Bob         52    85       96    100   75       54
# Tom         40    98       93     54   33       20
# Jason      100    97       54     55  100       88
# Marry       72    67       64     53   87       83
# Julia       45    90      100     55   34       96
# John        99    47       85     56   60      100
# Cathy      100    36       89     64   85       50
# Andy        85    36       45     79   84       39

# %%
df.head()
#前五筆資料
# Out:
#        Chinese  Math  Science  Music   PE  History
# Bob         52    85       96    100   75       54
# Tom         40    98       93     54   33       20
# Jason      100    97       54     55  100       88
# Marry       72    67       64     53   87       83
# Julia       45    90      100     55   34       96

# %%
df.tail()
#後五筆資料
# Out:
#        Chinese  Math  Science  Music  PE  History
# Marry       72    67       64     53  87       83
# Julia       45    90      100     55  34       96
# John        99    47       85     56  60      100
# Cathy      100    36       89     64  85       50
# Andy        85    36       45     79  84       39

# %%
df.sort_index(axis=1, ascending=True)
# Out:
#        Chinese  History  Math  Music   PE  Science
# Bob         52       54    85    100   75       96
# Tom         40       20    98     54   33       93
# Jason      100       88    97     55  100       54
# Marry       72       83    67     53   87       64
# Julia       45       96    90     55   34      100
# John        99      100    47     56   60       85
# Cathy      100       50    36     64   85       89
# Andy        85       39    36     79   84       45

# %%
df.sort_index(axis=0, ascending=True)
# Out:
#        Chinese  Math  Science  Music   PE  History
# Andy        85    36       45     79   84       39
# Bob         52    85       96    100   75       54
# Cathy      100    36       89     64   85       50
# Jason      100    97       54     55  100       88
# John        99    47       85     56   60      100
# Julia       45    90      100     55   34       96
# Marry       72    67       64     53   87       83
# Tom         40    98       93     54   33       20
